# %% [markdown]
# Import libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Reading dataset

# %%
data = pd.read_csv('/content/mobile_price_classification.csv')

# %% [markdown]
# Data Review

# %%
data.head()
# Out:
#    battery_power  bluetooth  clock_speed  dual_sim  front_cam  4G  int_memory  \
# 0            842          0          2.2         0          1   0           7
# 1           1021          1          0.5         1          0   1          53
# 2            563          1          0.5         1          2   1          41
# 3            615          1          2.5         0          0   0          10
# 4           1821          1          1.2         0         13   1          44
#
#    m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.6        188        2  ...         20       756  2549     9     7
# 1    0.7        136        3  ...        905      1988  2631    17     3
# 2    0.9        145        5  ...       1263      1716  2603    11     2
# 3    0.8        131        6  ...       1216      1786  2769    16     8
# 4    0.6        141        2  ...       1208      1212  1411     8     2
#
#    talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   battery_power   2000 non-null   int64
#  1   bluetooth       2000 non-null   int64
#  2   clock_speed     2000 non-null   float64
#  3   dual_sim        2000 non-null   int64
#  4   front_cam       2000 non-null   int64
#  5   4G              2000 non-null   int64
#  6   int_memory      2000 non-null   int64
#  7   m_dep           2000 non-null   float64
#  8   mobile_wt       2000 non-null   int64
#  9   n_cores         2000 non-null   int64
#  10  primary_camera  2000 non-null   int64
#  11  px_height       2000 non-null   int64
#  12  px_width        2000 non-null   int64
#  13  ram             2000 non-null   int64
#  14  sc_h            2000 non-null   int64
#  15  sc_w            2000 non-null   int64
#  16  talk_time       2000 non-null   int64
# ...

# %%
data.isna().sum()
# Out:
# battery_power     0
# bluetooth         0
# clock_speed       0
# dual_sim          0
# front_cam         0
# 4G                0
# int_memory        0
# m_dep             0
# mobile_wt         0
# n_cores           0
# primary_camera    0
# px_height         0
# px_width          0
# ram               0
# sc_h              0
# sc_w              0
# talk_time         0
# three_g           0
# touch_screen      0
# wifi              0
# price_range       0
# dtype: int64

# %%
data.shape
# Out:
# (2000, 21)

# %%
data.describe()
# Out:
#        battery_power  bluetooth  clock_speed     dual_sim    front_cam  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#                 4G   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %% [markdown]
# Spliting data into x&y

# %%
x = data.iloc[:,0:20]
y = data.iloc[:,20]

# %% [markdown]
# Scale the data using StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(x)

# %% [markdown]
# Train Test Split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)

# %% [markdown]
# Neural network Model

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %%
#creating sequential model
model = Sequential()
#adding layers
model.add(Dense(20,input_dim=20,activation='relu'))#using "relu" as acivation funtion
model.add(Dense(10, activation = "relu"))
model.add(Dense(4, activation = "softmax"))#using "softmax" as activation function for the output class hence it has more than two classes
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(x_train,y_train,epochs=100,validation_data=(x_test,y_test),verbose=1)
# Out:
# Epoch 1/100
# 44/44 [==============================] - 2s 14ms/step - loss: 1.5873 - accuracy: 0.2507 - val_loss: 1.4692 - val_accuracy: 0.2617
# Epoch 2/100
# 44/44 [==============================] - 0s 8ms/step - loss: 1.3942 - accuracy: 0.3250 - val_loss: 1.3618 - val_accuracy: 0.3283
# Epoch 3/100
# 44/44 [==============================] - 0s 6ms/step - loss: 1.3135 - accuracy: 0.3836 - val_loss: 1.3006 - val_accuracy: 0.3850
# Epoch 4/100
# 44/44 [==============================] - 0s 8ms/step - loss: 1.2543 - accuracy: 0.4321 - val_loss: 1.2420 - val_accuracy: 0.4100
# Epoch 5/100
# 44/44 [==============================] - 0s 6ms/step - loss: 1.1893 - accuracy: 0.4736 - val_loss: 1.1695 - val_accuracy: 0.4467
# Epoch 6/100
# 44/44 [==============================] - 0s 7ms/step - loss: 1.1065 - accuracy: 0.5214 - val_loss: 1.0787 - val_accuracy: 0.5067
# Epoch 7/100
# ...

# %% [markdown]
# Checking the test Accuracy

# %%
y_pred =model.predict(x_test)
# Out:
# 19/19 [==============================] - 0s 3ms/step

# %%
y_pred
# Out:
# array([[9.9998778e-01, 1.2102627e-05, 2.0337947e-14, 1.2098668e-35],
#        [9.9606221e-15, 3.0109914e-02, 9.6989000e-01, 2.0899790e-08],
#        [1.9822142e-08, 9.9999923e-01, 7.5852279e-07, 4.6715253e-27],
#        ...,
#        [9.9999982e-01, 1.4403599e-07, 5.4204742e-19, 0.0000000e+00],
#        [2.7244851e-09, 9.9887431e-01, 1.1257516e-03, 2.3933404e-17],
#        [9.9996608e-01, 3.3895471e-05, 6.6905823e-13, 1.7064717e-30]],
#       dtype=float32)

# %% [markdown]
# checking the accuracy of the model

# %%
model.evaluate(x_test, y_test)
# Out:
# 19/19 [==============================] - 0s 9ms/step - loss: 0.2577 - accuracy: 0.9033
# [0.2577053904533386, 0.903333306312561]

# %% [markdown]
# Accuracy of the model is 0.903

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Features','Price_Weight'],loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Features','Price_Weight'],loc='upper left')
plt.show()
